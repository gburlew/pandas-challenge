# %%
import pandas as pd
import json
from pathlib import Path
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt

from config import locations_age_csv
from config import vaccinations_age_csv
from config import vaccinations_manufacturer_csv

locations_age_data = pd.read_csv(locations_age_csv)
vaccinations_age_data = pd.read_csv(vaccinations_age_csv)
vaccinations_manufacturer_data = pd.read_csv(vaccinations_manufacturer_csv)

locations_age_data.head()
# Out:
#                                             location last_observation_date  \
# 0  .com/3dgiordano/covid-19-uy-vacc-data/main/dat...                   NaN
# 1  .com/3dgiordano/covid-19-uy-vacc-data/main/dat...                   NaN
# 2                                          Argentina            2024-01-28
# 3                                          Australia            2023-03-17
# 4                                            Austria            2023-06-30
#
#                                          source_name  \
# 0                                                NaN
# 1                                                NaN
# 2  Ministry of Health via https://covidstats.com....
# 3             Ministry of Health via covidbaseau.com
# 4  European Centre for Disease Prevention and Con...
#
#                                           source_url
# 0                                                NaN
# 1                                                NaN
# ...
